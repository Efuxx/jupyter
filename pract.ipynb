# %%
a = 3
b = 23
c = a + b

# %%
print(c)
# Out:
# 26

# %% [markdown]
# # 123 #
# ## 123 ##
# ![describe](https://pythonforfinance.net/wp-content/uploads/2019/07/Jupyter.jpg)
# $$m=\sqrt{4}$$

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.5.1-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#
# ...
#   Using cached fonttools-4.28.5-py3-none-any.whl (890 kB)
# ...
#   Using cached kiwisolver-1.3.2-cp310-cp310-win_amd64.whl (52 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = [-2,-1, 0, 1, 2]
y = [3, 1, 0, 1, 3]

# %%
plt.plot(x,y)

# %%
# %%time
import time
time.sleep(1)
# Out:
# CPU times: total: 0 ns
# Wall time: 1.01 s

# %%
# %matplotlib inline
plt.plot(x,y)

# %%
# %prun
plt.plot(x,y)
